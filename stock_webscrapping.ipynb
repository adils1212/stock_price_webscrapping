# %%
from bs4 import BeautifulSoup
import requests
from urllib.request import urlopen
import ssl
import re
import time as t

# %%
f_name='stock.csv'
f=open(f_name,"w")
headers="Price_of_stock, time, Market_Open/Close\n"
f.write(headers)
# Out:
# 40

# %%
# Ignore SSL certificate errors
# ctx = ssl.create_default_context()
# ctx.check_hostname = False
# ctx.verify_mode = ssl.CERT_NONE

# url = input('Enter - ')
url='https://finance.yahoo.com/quote/AAPL?p=AAPL&.tsrc=fin-srch'
html = requests.get(url).text
soup = BeautifulSoup(html, "html.parser")
t.sleep(5)
while True:
    html = requests.get(url).text
    soup = BeautifulSoup(html, "html.parser")
    price=soup.findAll('div',{'class':'D(ib) Mend(20px)'})
    time=soup.findAll('div',{'class':'C($tertiaryColor) D(b) Fz(12px) Fw(n) Mstart(0)--mobpsm Mt(6px)--mobpsm'})[0].find('span').text
    time_f=re.findall('[0-9]+:[0-9]+.M',time)[0]
    status=re.findall('Ma.+',time)[0]
    price=price[0].find('span',{'class':'Trsdu(0.3s) Fw(b) Fz(36px) Mb(-4px) D(ib)'}).text
    print(price)

    print(time_f)
    print(time)
    print(status)
    t.sleep(10)
    f.write(price+','+time_f+','+status+'\n')

f.close()
   

# <div id="quote-market-notice" class="C($tertiaryColor) D(b) Fz(12px) Fw(n) Mstart(0)--mobpsm Mt(6px)--mobpsm" data-reactid="52"><span data-reactid="53">As of  2:44PM EST. Market open.</span></div>
# Retrieve all of the anchor tags
# tags = soup('a')
# for tag in tags:
#     # Look at the parts of a tag
#     print('TAG:', tag['href'])
#     print('URL:', tag.get('href', None))
#     print('Contents:', tag.contents[0])
#     print('Attrs:', tag.attrs['href'])
# Out:
# 116.39
# 3:14PM
# As of  3:14PM EST. Market open.
# Market open.
# 116.32
# 3:14PM
# As of  3:14PM EST. Market open.
# Market open.
# 116.30
# 3:14PM
# As of  3:14PM EST. Market open.
# Market open.
# 116.38
# 3:14PM
# As of  3:14PM EST. Market open.
# Market open.
# 116.38
# 3:14PM
# As of  3:14PM EST. Market open.
# Market open.
# 116.33
# 3:15PM
# As of  3:15PM EST. Market open.
# Market open.
# 116.40
# 3:15PM
# As of  3:15PM EST. Market open.
# Market open.
# 116.42
# 3:15PM
# As of  3:15PM EST. Market open.
# Market open.
# 116.52
# 3:15PM
# As of  3:15PM EST. Market open.
# Market open.
# 116.46
# 3:15PM
# As of  3:15PM EST. Market open.
# Market open.
# 116.48
# 3:16PM
# As of  3:16PM EST. Market open.
# Market open.
# 116.47
# 3:16PM
# As of  3:16PM EST. Market open.
# Market open.
# 116.53
# 3:16PM
# As of  3:16PM EST. Market open.
# Market open.
# 116.49
# 3:16PM
# As of  3:16PM EST. Market open.
# Market open.
# 116.46
# 3:16PM
# As of  3:16PM EST. Market open.
# ...
